# %% [markdown]
# <a href="https://colab.research.google.com/github/pkmariya/Scaler01/blob/master/FoundationCore_MT01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Qn 1: Write code to find the maximum, avarage, and minimum price value for each category given a .csv file with the columns “Price”, “Category_SubCategory”
#
# Example:
# Price  		Category_SubCategory
# 234 		Tops_croptop
# 282 		Tops_croptop
# 222 		Tops_tshirt
# 382 		Tops_tshirt
# 2382 		BottomWear_jeans
# 2212 		BottomWear_jeans
# 1282 		BottomWear_leggings
# 212 		BottomWear_leggings
# You need to print the minimum value of Tops and BottomWear

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data_df = pd.read_csv('/content/CategoryPrice.csv')

# %%
data_df
# Out:
#    Price             Category
# 0    234         Tops_croptop
# 1    282         Tops_croptop
# 2    222          Tops_tshirt
# 3    382          Tops_tshirt
# 4   2382     BottomWear_jeans
# 5   2212     BottomWear_jeans
# 6   1282  BottomWear_leggings
# 7    212  BottomWear_leggings

# %%
data_df.head()
# Out:
#    Price          Category
# 0    234      Tops_croptop
# 1    282      Tops_croptop
# 2    222       Tops_tshirt
# 3    382       Tops_tshirt
# 4   2382  BottomWear_jeans

# %%
data_df
# Out:
#    Price             Category
# 0    234         Tops_croptop
# 1    282         Tops_croptop
# 2    222          Tops_tshirt
# 3    382          Tops_tshirt
# 4   2382     BottomWear_jeans
# 5   2212     BottomWear_jeans
# 6   1282  BottomWear_leggings
# 7    212  BottomWear_leggings

# %%
data_df['Price'].min()
# Out:
# 212

# %% [markdown]
# ### Max Price by Category

# %%
# Max Price by Category
data_df.groupby('Category')['Price'].max()
# Out:
# Category
# BottomWear_jeans       2382
# BottomWear_leggings    1282
# Tops_croptop            282
# Tops_tshirt             382
# Name: Price, dtype: int64

# %%
data_df.groupby('Category')['Price'].max().reset_index()
# Out:
#               Category  Price
# 0     BottomWear_jeans   2382
# 1  BottomWear_leggings   1282
# 2         Tops_croptop    282
# 3          Tops_tshirt    382

# %%
max_result = data_df.groupby('Category')['Price'].max().reset_index().sort_values(by='Price', ascending=True)
max_result.columns = ['Category', 'Max_Price']
print(max_result)
# Out:
#               Category  Max_Price
# 2         Tops_croptop        282
# 3          Tops_tshirt        382
# 1  BottomWear_leggings       1282
# 0     BottomWear_jeans       2382

# %%
max_result
# Out:
#               Category  Max_Price
# 2         Tops_croptop        282
# 3          Tops_tshirt        382
# 1  BottomWear_leggings       1282
# 0     BottomWear_jeans       2382

# %% [markdown]
# ### Average Price by Category

# %%
# Average Price by Category
avg_result = data_df.groupby('Category')['Price'].mean().reset_index().sort_values(by='Price')
avg_result.columns = ['Category', 'Average']
print(avg_result)
# Out:
#               Category  Average
# 2         Tops_croptop    258.0
# 3          Tops_tshirt    302.0
# 1  BottomWear_leggings    747.0
# 0     BottomWear_jeans   2297.0

# %%
avg_result
# Out:
#               Category  Average
# 2         Tops_croptop    258.0
# 3          Tops_tshirt    302.0
# 1  BottomWear_leggings    747.0
# 0     BottomWear_jeans   2297.0

# %% [markdown]
# ### Min Price by Category

# %%
# Min Price by Category
min_result = data_df.groupby('Category')['Price'].min().reset_index().sort_values(by='Price')
min_result.columns = ['Category', 'Min_Price']
print(min_result)
# Out:
#               Category  Min_Price
# 1  BottomWear_leggings        212
# 3          Tops_tshirt        222
# 2         Tops_croptop        234
# 0     BottomWear_jeans       2212

# %%
min_result
# Out:
#               Category  Min_Price
# 1  BottomWear_leggings        212
# 3          Tops_tshirt        222
# 2         Tops_croptop        234
# 0     BottomWear_jeans       2212

# %% [markdown]
# ### All at once - Max Price, Average and Min Price

# %%
data_df.groupby('Category').agg({'Price' : ['max', 'mean', 'min']}).reset_index()
# Out:
#               Category Price
#                          max    mean   min
# 0     BottomWear_jeans  2382  2297.0  2212
# 1  BottomWear_leggings  1282   747.0   212
# 2         Tops_croptop   282   258.0   234
# 3          Tops_tshirt   382   302.0   222

# %%
result = data_df.groupby('Category').agg({'Price' : ['max', 'mean', 'min']}).reset_index()
result.columns = ['Category', 'Max_Price', 'Average', 'Min_Price']
result
# Out:
#               Category  Max_Price  Average  Min_Price
# 0     BottomWear_jeans       2382   2297.0       2212
# 1  BottomWear_leggings       1282    747.0        212
# 2         Tops_croptop        282    258.0        234
# 3          Tops_tshirt        382    302.0        222

# %%
# Sort by Max Price
result.sort_values(by='Max_Price', ascending=True)
# Out:
#               Category  Max_Price  Average  Min_Price
# 2         Tops_croptop        282    258.0        234
# 3          Tops_tshirt        382    302.0        222
# 1  BottomWear_leggings       1282    747.0        212
# 0     BottomWear_jeans       2382   2297.0       2212

# %% [markdown]
# ### Min Value of Tops & BottomWear

# %%
data_df[['Category', 'SubCategory']] = data_df['Category'].str.split('_', 1, expand=True)
# Out:
# <ipython-input-51-9952e48cec7e>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   data_df[['Category', 'SubCategory']] = data_df['Category'].str.split('_', 1, expand=True)

# %%
tops_min = data_df[data_df['Category']=='Tops']['Price'].min()
tops_min
# Out:
# 222

# %%
bottomwear_min = data_df[data_df['Category']=='BottomWear']['Price'].min()
bottomwear_min
# Out:
# 212

# %%
data = [['Tops_Min', tops_min], ['BottomWear_Min', bottomwear_min]]

# %%
tops_bottomwear_mins = pd.DataFrame(data)

# %%
tops_bottomwear_mins.columns = ['Category', 'Min_Value']
tops_bottomwear_mins
# Out:
#          Category  Min_Value
# 0        Tops_Min        222
# 1  BottomWear_Min        212

# %% [markdown]
# ## Qn 2: Run a Python program to do run length encoding example “abbcdd --> a1b3c1d2“
#
#
# Here's a Python program to perform run-length encoding (RLE) on a given string

# %%
def run_length_encode(inp_str):
  encoded = ''
  count = 1

  for i in range(1, len(inp_str)):
    if inp_str[i] == inp_str[i-1]:
      count += 1
    else:
      encoded += inp_str[i-1] + str(count)
      count = 1

  encoded += inp_str[-1] + str(count)

  return encoded

# %%
s = 'abbbcdd'
print("Original String: ", s)
print("Encoded String : ", run_length_encode(s))
# Out:
# Original String:  abbbcdd
# Encoded String :  a1b3c1d2

# %%
data_df
# Out:
#    Price             Category
# 0    234         Tops_croptop
# 1    282         Tops_croptop
# 2    222          Tops_tshirt
# 3    382          Tops_tshirt
# 4   2382     BottomWear_jeans
# 5   2212     BottomWear_jeans
# 6   1282  BottomWear_leggings
# 7    212  BottomWear_leggings

# %%
# Max value by Category
max_by_cat = data_df.groupby('Category')['Price'].max().reset_index()
max_by_cat.columns = ['Category', 'Max_Price']
max_by_cat
# Out:
#               Category  Max_Price
# 0     BottomWear_jeans       2382
# 1  BottomWear_leggings       1282
# 2         Tops_croptop        282
# 3          Tops_tshirt        382

# %%
# Min value by Category
min_by_cat = data_df.groupby('Category')['Price'].min().reset_index()
min_by_cat.columns = ['Category', 'Min_Price']
min_by_cat
# Out:
#               Category  Min_Price
# 0     BottomWear_jeans       2212
# 1  BottomWear_leggings        212
# 2         Tops_croptop        234
# 3          Tops_tshirt        222

# %%
# Mean value by Category
avg_by_cat = data_df.groupby('Category')['Price'].mean().reset_index()
avg_by_cat.columns = ['Category', 'Mean Value']
avg_by_cat
# Out:
#               Category  Mean Value
# 0     BottomWear_jeans      2297.0
# 1  BottomWear_leggings       747.0
# 2         Tops_croptop       258.0
# 3          Tops_tshirt       302.0

# %%
data_df
# Out:
#    Price             Category
# 0    234         Tops_croptop
# 1    282         Tops_croptop
# 2    222          Tops_tshirt
# 3    382          Tops_tshirt
# 4   2382     BottomWear_jeans
# 5   2212     BottomWear_jeans
# 6   1282  BottomWear_leggings
# 7    212  BottomWear_leggings

# %%
data_df[['Category', 'SubCategory']] = data_df['Category'].str.split('_', 1, expand=True)
data_df
# Out:
#    Price    Category SubCategory
# 0    234        Tops     croptop
# 1    282        Tops     croptop
# 2    222        Tops      tshirt
# 3    382        Tops      tshirt
# 4   2382  BottomWear       jeans
# 5   2212  BottomWear       jeans
# 6   1282  BottomWear    leggings
# 7    212  BottomWear    leggings

# %%
max_of_cat = data_df.groupby('Category')['Price'].max().reset_index()
max_of_cat.columns = ['Category', 'Max_Price_by_Category']

# %%
max_of_cat
# Out:
#      Category  Max_Price_by_Category
# 0  BottomWear                   2382
# 1        Tops                    382

# %%
data_df
# Out:
#    Price    Category SubCategory
# 0    234        Tops     croptop
# 1    282        Tops     croptop
# 2    222        Tops      tshirt
# 3    382        Tops      tshirt
# 4   2382  BottomWear       jeans
# 5   2212  BottomWear       jeans
# 6   1282  BottomWear    leggings
# 7    212  BottomWear    leggings

# %%
# Max Price by Category cum Sub Category
max_by_cat_subcat = data_df.groupby(['Category', 'SubCategory'])['Price'].max().reset_index()
max_by_cat_subcat
# Out:
#      Category SubCategory  Price
# 0  BottomWear       jeans   2382
# 1  BottomWear    leggings   1282
# 2        Tops     croptop    282
# 3        Tops      tshirt    382

# %%
# Min Price by Category cum Subcategory
min_by_cat_subcat = data_df.groupby(['Category', 'SubCategory'])['Price'].min().reset_index()
min_by_cat_subcat
# Out:
#      Category SubCategory  Price
# 0  BottomWear       jeans   2212
# 1  BottomWear    leggings    212
# 2        Tops     croptop    234
# 3        Tops      tshirt    222

# %%
# Min Price in Tops Category
min_price_tops = data_df[data_df['Category']=='Tops']['Price'].min()
print("Min Price in Tops is: ", min_price_tops)
# Out:
# Min Price in Tops is:  222

# %%
# Max Price in BottomWears
max_price_bottomwear = data_df[data_df['Category']=='BottomWear']['Price'].max()
print("Max Price in Bottomwear is: ", max_price_bottomwear)
# Out:
# Max Price in Bottomwear is:  2382

# %%
# Max Price in the given list
print("Max Price of the given list: ", data_df['Price'].max())
# Out:
# Max Price of the given list:  2382

# %%
# Min price of the given list
print("Min Price in the given list: ", data_df.Price.min())
# Out:
# Min Price in the given list:  212
